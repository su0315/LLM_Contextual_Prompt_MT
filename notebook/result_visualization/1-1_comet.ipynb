# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# XGLM 1-1

def get_score(context_size, model):
    disk_dir = "/mnt/data-poseidon/sumire/thesis"
    #xglm_path = f'/1-1/en-{lang}/xglm-{lang}-1-1/test_score.txt'
    #llama_path = f'/1-1/en-{lang}/llama-{lang}-1-1/test_score.txt'

    lang_list = os.listdir(disk_dir + f"/{context_size}")
    for id, lang in enumerate(lang_list):
        lang_list[id] = lang_list[id].replace("en-", "")

    lang_scores = {}
    
    """
    #for model_path in [xglm_path, llama_path]:
    if model == "Llama-2-70b-instruct-v2":
        folder = "1-1"
    
    else: 
        folder = "1-1_withoutContext"
    """
    
    for lang in lang_list: # Change: context_size into 1-1_Wihout_context 
        score_path = disk_dir+f'/{context_size}/en-{lang}/{model}-{lang}-1-1/test_score.txt'
        if os.path.exists(score_path):
            with open(score_path,'r') as wf:
                lang_scores[lang] = wf.readlines()
                
        else:    
            lang_scores[lang] = ["bleu: 0", "comet: 0", "gen_len: 0"]
       
    #print (lang_scores) #str.replace("\n", "")

    # Sample data: replace this with your actual data
    bleu_list = []
    comet_list = []
    for score_list in lang_scores.values():
        bleu = score_list[0]
        bleu = bleu.replace("bleu: ", "")
        bleu = bleu.replace("\n", "")
        bleu = float(bleu)
        
        comet = score_list[1]
        comet = comet.replace("comet: ", "")
        comet = comet.replace("\n", "")
        comet = float(comet)
        bleu_list.append(bleu)
        comet_list.append(comet)
    return comet_list, bleu_list, lang_list

# %%
xglm_comet_list, xglm_bleu_list, lang_list = get_score("1-1","xglm")
print ("XGLM", lang_list)
print ("COMET: ", xglm_comet_list)
print ("BLEU: ", xglm_bleu_list)
print ()
llama_comet_list, llama_bleu_list, lang_list = get_score("1-1","llama")
print ("Llama", lang_list)
print ("COMET", llama_comet_list)
print ("BLEU", llama_bleu_list)
print ()
mbart_comet_list, mbart_bleu_list, lang_list = get_score("1-1","mbart")
print ("mBART", lang_list)
print ("COMET", mbart_comet_list)
print ("BLEU", mbart_bleu_list)
print ()

#llama2_70b_comet_list, llama2_70b_bleu_list, lang_list = get_score("1-1","Llama-2-70b-instruct-v2")
#print ("Llama2_70b with ar sentencepiece BLEU tokenizer", lang_list)
llama2_70b_comet_list, llama2_70b_bleu_list, lang_list = get_score("1-1","Llama-2-70b-instruct-v2-usas-zs-p1-nsplit")
print ("Llama-2-70b-instruct-v2-usas-zs-p1-nsplit")
print ("COMET", llama2_70b_comet_list)
print ("BLEU", llama2_70b_bleu_list)

mbart_comet_list, mbart_bleu_list, lang_list = get_score("1-1","mbart")
print ("mbart")
print ("COMET", llama2_70b_comet_list)
print ("BLEU", llama2_70b_bleu_list)
# Out:
# XGLM ['ar', 'fr', 'ja', 'ko', 'de', 'zh']
# COMET:  [0.7372127388535029, 0.6437683624801279, 0.6951377419354833, 0.7196388349514563, 0.6694324414715717, 0.7457514376996807]
# BLEU:  [9.58069426751592, 19.267324960254392, 6.017918709677419, 8.813881553398058, 14.72452173913043, 16.09243466453673]
#
# Llama ['ar', 'fr', 'ja', 'ko', 'de', 'zh']
# COMET [0.49616656050955443, 0.5683147853736094, 0.5432054838709677, 0.42161197411003254, 0.46313478260869567, 0.6262217426059161]
# BLEU [1.6762554140127386, 17.025433227345005, 2.8729951612903224, 0.837695792880259, 8.088846488294314, 11.798203037569937]
#
# mBART ['ar', 'fr', 'ja', 'ko', 'de', 'zh']
# COMET [0.8127000000000001, 0.8129875000000002, 0.809051282051282, 0.8370820512820513, 0.8154763157894738, 0.8054731629392973]
# BLEU [13.646044999999996, 34.35230000000001, 12.974720512820518, 19.201128205128203, 28.694407894736838, 22.59986070287539]
#
# Llama-2-70b-instruct-v2-usas-zs-p1-nsplit
# COMET [0.7687, 0.8496, 0.8335, 0.8358, 0.8411, 0.8237]
# BLEU [15.4724, 39.5985, 12.7165, 17.0204, 30.0052, 28.6821]
# mbart
# COMET [0.7687, 0.8496, 0.8335, 0.8358, 0.8411, 0.8237]
# BLEU [15.4724, 39.5985, 12.7165, 17.0204, 30.0052, 28.6821]

# %%
# Generating positions for the bars
x = np.arange(len(lang_list))  # The label locations
width = 0.1  # The width of the bars
plt.rcParams.update({'font.size': 12})#fontsize=12
# Creating the plot
fig, ax = plt.subplots(figsize=(10, len(lang_list)))
rects1 = ax.bar(x - width*1.5, mbart_comet_list, width, label='mBART (k=0)')
rects2 = ax.bar(x - width*0.5, xglm_comet_list, width, label='XGLM (k=4)')
rects4 = ax.bar(x + width * 0.5, llama_comet_list, width, label='LLAMA7b (k=4)')
rects6 = ax.bar(x +width*1.5, llama2_70b_comet_list, width, label='Llama-2-70b-instruct-v2 (k=0)')
# mBART ko/zh tokenizer models

# Adding labels and title
ax.set_xlabel('Languages')
ax.set_ylabel('Scores')
ax.set_title('COMET score for different languages')
ax.set_xticks(x)
ax.set_xticklabels(lang_list)
ax.legend()

# Adjust the x-axis limits for better visualization
ax.set_xlim(-0.5, len(lang_list) - 0.5)
ax.legend(loc='lower right')

# Displaying the plot
plt.tight_layout()
plt.show()

# %%
# Generating positions for the bars
x = np.arange(len(lang_list))  # The label locations
plt.rcParams.update({'font.size': 12})#fontsize=12
width = 0.1  # The width of the bars

# Creating the plot
fig, ax = plt.subplots(figsize=(10, len(lang_list)))
rects1 = ax.bar(x - width*1.5, mbart_bleu_list, width, label='mBART (k=0)')
rects4 = ax.bar(x - width*0.5, xglm_bleu_list, width, label='XGLM (k=4)')
rects2 = ax.bar(x+width*0.5, llama_bleu_list, width, label='LLAMA7b (k=4)')
rects12 = ax.bar(x +width*1.5, llama2_70b_bleu_list, width, label='Llama-2-70b-instruct-v2 (k=0)')


# Adding labels and title
ax.set_xlabel('Languages')
ax.set_ylabel('Scores')
ax.set_title('BLEU score for different languages')
ax.set_xticks(x)
ax.set_xticklabels(lang_list)
ax.legend()

# Adjust the x-axis limits for better visualization
ax.set_xlim(-0.5, len(lang_list) - 0.5)
ax.legend(loc='upper right')

#plt.yticks(range(0, 55,5))

# Displaying the plot
plt.tight_layout()
plt.show()
